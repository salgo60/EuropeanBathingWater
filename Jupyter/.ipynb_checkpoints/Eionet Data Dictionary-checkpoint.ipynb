# %% [markdown]
# Get all Bathing Waters with P9618 in this project from Wikidata and checks if they exist on eionet as a WaterBody
#
# https://dd.eionet.europa.eu/vocabularyconcept/wise/WaterBody
#
# * The project: [github salgo60/Svenskabadplatser](https://github.com/salgo60/Svenskabadplatser)
#   * European bathwaters [GITHUB](https://github.com/salgo60/EuropeanBathingWater/blob/main/README.md) / [Wikidata](https://www.wikidata.org/wiki/Wikidata:WikiProject_European_Bath_Waters)
# * this [Notebook](https://github.com/salgo60/EuropeanBathingWater/blob/main/Jupyter/Eionet%20Data%20Dictionary.ipynb)
#
#
# Status:
#
#
#
# | Date | Total | Ok | Error
# | ------------- |:-------------:|:-------------:|:-------------:|
# | 20210610 | 3176 | 936 | 2240 |

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2021-06-12 10:54:05.844110

# %%
import pandas as pd

# %%
#
# pip install sparqlwrapper
# https://rdflib.github.io/sparqlwrapper/

import sys,json
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"
 
# https://w.wiki/3Tk$    
queryBath = """SELECT  (REPLACE(STR(?nodebath), ".*Q", "Q") AS ?wikidata) ?nodebath (SUBSTR(lcase(?bath),1,2) AS ?country)
(URI(CONCAT("https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.",
       str(?bath))) AS ?eionet)  (str(?bath) AS ?bathwateridentifier){
      # ?nodebath wdt:P9616 ?bath} 
"""


def get_sparql_dataframe(endpoint_url, query):
    """
    Helper function to convert SPARQL results into a Pandas data frame.
    """
    user_agent = "salgo60/%s.%s" % (sys.version_info[0], sys.version_info[1])
 
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()

    processed_results = json.load(result.response)
    cols = processed_results['head']['vars']

    out = []
    for row in processed_results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)

    return pd.DataFrame(out, columns=cols)

WDBath = get_sparql_dataframe(endpoint_url, queryBath)
WDBath.shape
# Out:
# (3170, 5)

# %%
WDBath.head()
# Out:
#      wikidata                                   nodebath country  \
# 0  Q106702261  http://www.wikidata.org/entity/Q106702261      se
# 1  Q106703325  http://www.wikidata.org/entity/Q106703325      se
# 2  Q106702259  http://www.wikidata.org/entity/Q106702259      se
# 3  Q106702279  http://www.wikidata.org/entity/Q106702279      se
# 4  Q106704485  http://www.wikidata.org/entity/Q106704485      se
#
#                                               eionet bathwateridentifier
# 0  https://dd.eionet.europa.eu/vocabularyconcept/...  SE0411080000000216
# 1  https://dd.eionet.europa.eu/vocabularyconcept/...  SE0210380000001180
# 2  https://dd.eionet.europa.eu/vocabularyconcept/...  SE0411080000000212
# 3  https://dd.eionet.europa.eu/vocabularyconcept/...  SE0210380000001177
# 4  https://dd.eionet.europa.eu/vocabularyconcept/...  SE0210380000005939

# %%
import urllib3, json
from tqdm import tqdm
http = urllib3.PoolManager()
urlHav = "https://badplatsen.havochvatten.se/badplatsen/api/detail/" 

listBath = []
for WD, row in tqdm(WDBath.iterrows(), total=WDBath.shape[0]):
    url = row["eionet"] 
    
    new_item = dict()
    new_item['wikidata'] = row["wikidata"] 
    #print(url)
    try:
        r = http.request('GET', url) 
        new_item['status'] = r.status
        if  r.status == 404 and row['country'] == "se":
            #Check if Sweden. and check API for reason
            try:
                urlHavBath = urlHav + row["bathwateridentifier"]
                rHav = http.request('GET',urlHavBath , 
                                    headers={'Content-Type': 'application/json'})
                rHavData = json.loads(rHav.data.decode('utf-8'))  
                #for key, value in rHavData.items() :
                #    print ("\t\t",key, value)
                new_item['euType'] = rHavData["euType"]
                new_item['euMotive'] = rHavData["euMotive"]
                new_item['NotEuMotive'] = rHavData["NotEuMotive"]
                
            except Exception as e:
                print ("Hav except ", e, urlHavBath, " WD:",row["wikidata"] )

    except:
        #print (r.status, url)
        new_item['status'] = r.status
    new_item['eionet'] = url 
    new_item['bathwateridentifier'] = row["bathwateridentifier"] 
    new_item['country'] = row["country"] 
    
    listBath.append(new_item)
print (len(listBath))
# Out:
# 100%|██████████| 3170/3170 [03:04<00:00, 17.16it/s]
# 3170

# %%
#listBath

# %%
Eionettot = pd.DataFrame(listBath,
                  columns=['wikidata','country','bathwateridentifier','status','eionet','euType','euMotive','NotEuMotive'])
Eionettot.shape
# Out:
# (3170, 8)

# %%
Eionettot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3170 entries, 0 to 3169
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   wikidata             3170 non-null   object
#  1   country              3170 non-null   object
#  2   bathwateridentifier  3170 non-null   object
#  3   status               3170 non-null   int64
#  4   eionet               3170 non-null   object
#  5   euType               2202 non-null   object
#  6   euMotive             17 non-null     object
#  7   NotEuMotive          0 non-null      float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 198.2+ KB

# %%
pd.set_option('max_colwidth', 400)
Eionettot.head(10)
# Out:
#      wikidata country bathwateridentifier  status  \
# 0  Q106702261      se  SE0411080000000216     200
# 1  Q106703325      se  SE0210380000001180     200
# 2  Q106702259      se  SE0411080000000212     200
# 3  Q106702279      se  SE0210380000001177     404
# 4  Q106704485      se  SE0210380000005939     404
# 5  Q106702258      se  SE0411080000000213     200
# 6  Q106702255      se  SE0411080000000207     404
# 7  Q106702253      se  SE0411080000000204     200
# 8  Q106705861      se  SE0632180000002897     404
# 9  Q106705867      se  SE0632180000002885     404
#
#                                                                                                        eionet  \
# 0  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0411080000000216
# 1  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0210380000001180
# 2  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0411080000000212
# 3  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0210380000001177
# 4  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0210380000005939
# 5  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0411080000000213
# 6  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0411080000000207
# 7  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0411080000000204
# 8  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0632180000002897
# 9  https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0632180000002885
#
#   euType                                                             euMotive  \
# 0    NaN                                                                  NaN
# 1    NaN                                                                  NaN
# 2    NaN                                                                  NaN
# 3  False                                                                 None
# 4  False                                                                 None
# 5    NaN                                                                  NaN
# 6   True  Antalet besökare uppskattas till runt 500 personer fina sommardagar
# 7    NaN                                                                  NaN
# 8  False                                                                 None
# 9  False                                                                 None
#
#    NotEuMotive
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN

# %%
#Eionettot["link"] = "<a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode." + Eionettot["eionet"].astype(str) + "'">link eionet</a>"
Eionettot["link"] = "<a href='" + Eionettot["eionet"].astype(str) + "'>link eionet</a>"
Eionettot["WD"] = "<a href='https://www.wikidata.org/wiki/" + Eionettot["wikidata"].astype(str) + "'>link WD</a>"

# %%
from IPython.display import display, HTML  

#Eionettot.value_counts({"status","country"})
#Eionettot[['status', 'country']].apply(pd.Series.value_counts)
HTML(Eionettot[{'WD','country','bathwateridentifier','status','link','euType','euMotive','NotEuMotive'}].tail(50).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>euMotive</th>
#       <th>euType</th>
#       <th>country</th>
#       <th>NotEuMotive</th>
#       <th>WD</th>
#       <th>status</th>
#       <th>link</th>
#       <th>bathwateridentifier</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3120</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708321'>link WD</a></td>
#       <td>200</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0230563000001314'>link eionet</a></td>
#       <td>SE0230563000001314</td>
#     </tr>
#     <tr>
#       <th>3121</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708323'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0920781000001317'>link eionet</a></td>
#       <td>SE0920781000001317</td>
#     </tr>
#     <tr>
#       <th>3122</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708324'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0920781000001318'>link eionet</a></td>
#       <td>SE0920781000001318</td>
#     </tr>
#     <tr>
#       <th>3123</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708325'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0920781000001319'>link eionet</a></td>
#       <td>SE0920781000001319</td>
#     </tr>
#     <tr>
#       <th>3124</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708326'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0920781000001320'>link eionet</a></td>
#       <td>SE0920781000001320</td>
#     </tr>
#     <tr>
#       <th>3125</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708313'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0920781000001303'>link eionet</a></td>
#       <td>SE0920781000001303</td>
#     </tr>
#     <tr>
#       <th>3126</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708328'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0920781000001322'>link eionet</a></td>
#       <td>SE0920781000001322</td>
#     </tr>
#     <tr>
#       <th>3127</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708322'>link WD</a></td>
#       <td>200</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0230563000001315'>link eionet</a></td>
#       <td>SE0230563000001315</td>
#     </tr>
#     <tr>
#       <th>3128</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708327'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0920781000001321'>link eionet</a></td>
#       <td>SE0920781000001321</td>
#     </tr>
#     <tr>
#       <th>3129</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708329'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0920781000001323'>link eionet</a></td>
#       <td>SE0920781000001323</td>
#     </tr>
#     <tr>
#       <th>3130</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708330'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0920781000001324'>link eionet</a></td>
#       <td>SE0920781000001324</td>
#     </tr>
#     <tr>
#       <th>3131</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708331'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0920781000001325'>link eionet</a></td>
#       <td>SE0920781000001325</td>
#     </tr>
#     <tr>
#       <th>3132</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708346'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0920781000001326'>link eionet</a></td>
#       <td>SE0920781000001326</td>
#     </tr>
#     <tr>
#       <th>3133</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708349'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0920781000001328'>link eionet</a></td>
#       <td>SE0920781000001328</td>
#     </tr>
#     <tr>
#       <th>3134</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708347'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0920781000001327'>link eionet</a></td>
#       <td>SE0920781000001327</td>
#     </tr>
#     <tr>
#       <th>3135</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708355'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0A21442000001331'>link eionet</a></td>
#       <td>SE0A21442000001331</td>
#     </tr>
#     <tr>
#       <th>3136</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708356'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0A21442000001332'>link eionet</a></td>
#       <td>SE0A21442000001332</td>
#     </tr>
#     <tr>
#       <th>3137</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708358'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0A21442000001333'>link eionet</a></td>
#       <td>SE0A21442000001333</td>
#     </tr>
#     <tr>
#       <th>3138</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708360'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0A21442000001334'>link eionet</a></td>
#       <td>SE0A21442000001334</td>
#     </tr>
#     <tr>
#       <th>3139</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q1067

# %%
EionettotOk = Eionettot[(Eionettot['status']==200)] 
EionettotError = Eionettot[(Eionettot['status']==404)]

# %%
EionettotOk.shape
# Out:
# (936, 10)

# %%
EionettotError.shape
# Out:
# (2234, 10)

# %%
EionettotError.value_counts("country")
# Out:
# country
# se    2202
# es      13
# gr      12
# hr       4
# de       1
# ie       1
# uk       1
# dtype: int64

# %%
EionettotError.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2234 entries, 3 to 3169
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   wikidata             2234 non-null   object
#  1   country              2234 non-null   object
#  2   bathwateridentifier  2234 non-null   object
#  3   status               2234 non-null   int64
#  4   eionet               2234 non-null   object
#  5   euType               2202 non-null   object
#  6   euMotive             17 non-null     object
#  7   NotEuMotive          0 non-null      float64
#  8   link                 2234 non-null   object
#  9   WD                   2234 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 192.0+ KB

# %%
HTML(EionettotError[{'WD','country','bathwateridentifier','status','link','euType','euMotive','NotEuMotive'}].tail(10).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>euMotive</th>
#       <th>euType</th>
#       <th>country</th>
#       <th>NotEuMotive</th>
#       <th>WD</th>
#       <th>status</th>
#       <th>link</th>
#       <th>bathwateridentifier</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3160</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708394'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0A21446000001381'>link eionet</a></td>
#       <td>SE0A21446000001381</td>
#     </tr>
#     <tr>
#       <th>3161</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708402'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0920761000001395'>link eionet</a></td>
#       <td>SE0920761000001395</td>
#     </tr>
#     <tr>
#       <th>3162</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708407'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0920761000001397'>link eionet</a></td>
#       <td>SE0920761000001397</td>
#     </tr>
#     <tr>
#       <th>3163</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708408'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0920761000001398'>link eionet</a></td>
#       <td>SE0920761000001398</td>
#     </tr>
#     <tr>
#       <th>3164</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708391'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0A21446000001380'>link eionet</a></td>
#       <td>SE0A21446000001380</td>
#     </tr>
#     <tr>
#       <th>3165</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708410'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0A21460000001403'>link eionet</a></td>
#       <td>SE0A21460000001403</td>
#     </tr>
#     <tr>
#       <th>3166</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708411'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0A21460000001405'>link eionet</a></td>
#       <td>SE0A21460000001405</td>
#     </tr>
#     <tr>
#       <th>3167</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708413'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0A21460000001407'>link eionet</a></td>
#       <td>SE0A21460000001407</td>
#     </tr>
#     <tr>
#       <th>3168</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708414'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0A21460000001408'>link eionet</a></td>
#       <td>SE0A21460000001408</td>
#     </tr>
#     <tr>
#       <th>3169</th>
#       <td>None</td>
#       <td>False</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106708416'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0110127000001410'>link eionet</a></td>
#       <td>SE0110127000001410</td>
#     </tr>
#   </tbody>
# </table>

# %%
EionettotErrorEuType = EionettotError[EionettotError["euType"] == True] 
HTML(EionettotErrorEuType[{'WD','country','bathwateridentifier','status','link','euType','euMotive','NotEuMotive'}].tail(10).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>euMotive</th>
#       <th>euType</th>
#       <th>country</th>
#       <th>NotEuMotive</th>
#       <th>WD</th>
#       <th>status</th>
#       <th>link</th>
#       <th>bathwateridentifier</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>440</th>
#       <td>Badplatsen har fler än 200 besökare i genomsnitt normal sommardag.</td>
#       <td>True</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106707517'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0441293000000427'>link eionet</a></td>
#       <td>SE0441293000000427</td>
#     </tr>
#     <tr>
#       <th>1080</th>
#       <td>Uppskattningsvis badar fler än 200 personer här vid god väderlek under badsäsongen. Camping finns i anslutning till badplatsen.</td>
#       <td>True</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106710200'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0241860000003270'>link eionet</a></td>
#       <td>SE0241860000003270</td>
#     </tr>
#     <tr>
#       <th>1500</th>
#       <td>Många badande från Örebro p.g.a. närheten till E18, uppskattningsvis över 200 badande vid god väderlek.</td>
#       <td>True</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106711900'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0241814000004068'>link eionet</a></td>
#       <td>SE0241814000004068</td>
#     </tr>
#     <tr>
#       <th>1531</th>
#       <td>Vi bedömer att Skräcklan-barnbadet uppfyller kriterierna för EU-bad med över 200 badande per dag. Det är också en stadsnära badplats som är iordningsställd för bad med toalett och handikappramp. Det är även många skolklasser och fritids som är där och badar.</td>
#       <td>True</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106711936'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0A21487000004208'>link eionet</a></td>
#       <td>SE0A21487000004208</td>
#     </tr>
#     <tr>
#       <th>2043</th>
#       <td>Stora investeringar senaste åren intill en camping med mycket turister. Mer än 200 badande per dag 2019.</td>
#       <td>True</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106707863'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0930880000000781'>link eionet</a></td>
#       <td>SE0930880000000781</td>
#     </tr>
#     <tr>
#       <th>2049</th>
#       <td>Nyrenoverat hopptorn med flertalet badande över tid ca 250 personer per dag samt intilliggande aktivitetsområde. Här finns tillgång till basket och volleybollplaner samt utegym och flertalet grillplatser</td>
#       <td>True</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106707865'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0930880000000783'>link eionet</a></td>
#       <td>SE0930880000000783</td>
#     </tr>
#     <tr>
#       <th>2051</th>
#       <td>Mer än 200 badande per dag. Central badplats i Kalmar med mycket turister.</td>
#       <td>True</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106707868'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0930880000000786'>link eionet</a></td>
#       <td>SE0930880000000786</td>
#     </tr>
#     <tr>
#       <th>2052</th>
#       <td>Stora investeringar 2019 med en väl tilltagen brygga i ett populärt område i norra delarna av Kalmar. Fler än 200 badande per dag i snitt 2019.</td>
#       <td>True</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106707874'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0930880000000792'>link eionet</a></td>
#       <td>SE0930880000000792</td>
#     </tr>
#     <tr>
#       <th>2785</th>
#       <td>Trädäcken vid badplatsen Sundspromenaden är en naturlig och mycket populär mötesplats för alla sol- och badsugna under sommarhalvåret i Malmö men används även för vinterbadare. Besöksstatistiken för Sundspromenadens badplats har registrerats under badsäsongen som ca 3000-10000personer per vecka beroende på väder.</td>
#       <td>True</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106677306'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0441280000004499'>link eionet</a></td>
#       <td>SE0441280000004499</td>
#     </tr>
#     <tr>
#       <th>2868</th>
#       <td>En insjö med klart vatten som är en vattentäkt. Badplatsen är välbesökt året runt. Föreningen har gjort flera grillplatser, byggt en egen vacker grillkåta och byggt till lekplatsen på badplatsen. Badplatsen har ett bryggomslutet barnbad och ytterligare en brygga med hopptorn samt två flottar. Toaletter och omklädningsbås finns. Antalet besökare uppskattas till drygt 200 personer fina sommardagar.</td>
#       <td>True</td>
#       <td>se</td>
#       <td>NaN</td>
#       <td><a href='https://www.wikidata.org/wiki/Q106702268'>link WD</a></td>
#       <td>404</td>
#       <td><a href='https://dd.eionet.europa.eu/vocabularyconcept/wise/WFDProtectedArea/euProtectedAreaCode.SE0411080000000220'>link eionet</a></td>
#       <td>SE0411080000000220</td>
#     </tr>
#   </tbody>
# </table>

# %%
EionettotError["euMotive"].value_counts()
# Out:
# <200 badande per dag. Ej längre EU bad.                                                                                                                                                                                                                                                                                                                                                                            3
# Trädäcken vid badplatsen Sundspromenaden är en naturlig och mycket populär mötesplats för alla sol- och badsugna under sommarhalvåret i Malmö men används även för vinterbadare. Besöksstatistiken för Sundspromenadens badplats har registrerats under badsäsongen som ca 3000-10000personer per vecka beroende på väder.                                                                                         1
# Nyrenoverat hopptorn med flertalet badande över tid ca 250 personer per dag samt intilliggande aktivitetsområde. Här finns tillgång till basket och volleybollplaner samt utegym och flertalet grillplatser                                                                                                                                                                                                        1
# Mer än 200 badande per dag. Central badplats i Kalmar med mycket turister.                                                                                                                                                                                                                                                                                                                                         1
# Stora investeringar 2019 med en väl tilltagen brygga i ett populärt område i norra delarna av Kalmar. Fler än 200 badande per dag i snitt 2019.                                                                                                                                                                                                                                                                    1
# Vi bedömer att Skräcklan-barnbadet uppfyller kriterierna för EU-bad med över 200 badande per dag. Det är också en stadsnära badplats som är iordningsställd för bad med toalett och handikappramp. Det är även många skolklasser och fritids som är där och badar.                                                                                                                                                 1
# Felaktig inmatning                                                                                                                                                                                                                                                                                                                                                                                                 1
# Badet vid Gyllebosjön är mycket populärt och välbesökt. Badet har lösningar för tillgänglighetsanpassning.                                                                                                                                                                                                                                                                                                         1
# Uppskattningsvis badar fler än 200 personer här vid god väderlek under badsäsongen. Camping finns i anslutning till badplatsen.                                                                                                                                                                                                                                                                                    1
# Många badande från Örebro p.g.a. närheten till E18, uppskattningsvis över 200 badande vid god väderlek.                                                                                                                                                                                                                                                                                                            1
# Antalet besökare uppskattas till runt 500 personer fina sommardagar                                                                                                                                                                                                                                                                                                                                                1
# En insjö med klart vatten som är en vattentäkt. Badplatsen är välbesökt året runt. Föreningen har gjort flera grillplatser, byggt en egen vacker grillkåta och byggt till lekplatsen på badplatsen. Badplatsen har ett bryggomslutet barnbad och ytterligare en brygga med hopptorn samt två flottar. Toaletter och omklädningsbås finns. Antalet besökare uppskattas till drygt 200 personer fina sommardagar.    1
# Stora investeringar senaste åren intill en camping med mycket turister. Mer än 200 badande per dag 2019.                                                                                                                                                                                                                                                                                                           1
# Badplatsen har fler än 200 besökare i genomsnitt normal sommardag.                                                                                                                                                                                                                                                                                                                                                 1
# Badet i skydd av pirarmen i Baskemölla är mycket välbesökt av barnfamiljer.                                                                                                                                                                                                                                                                                                                                        1
# Name: euMotive, dtype: int64

# %%
EionettotOk.shape
# Out:
# (936, 10)

# %%
EionettotOk.value_counts("country")
# Out:
# country
# se    487
# dk     36
# de     35
# pt     33
# fr     27
# ie     24
# it     23
# lt     22
# fi     21
# uk     21
# es     21
# nl     20
# pl     20
# hu     17
# ee     17
# si     16
# bg     14
# ro     11
# hr     10
# at      9
# lv      9
# sk      8
# al      8
# lu      8
# be      7
# cz      6
# mt      6
# dtype: int64

# %%
EionettotOk.to_csv("BathIdentifier_Ok.csv")
EionettotError.to_csv("BathIdentifier_Error.csv")
Eionettot.to_csv("BathIdentifier_All.csv")

# %% [markdown]
# Generate Markdown table eg.
# | 20210610 | 3176 | 2240 | 936 |

# %%
print("|",start_time.strftime("%Y%m%d"),"|", \
      Eionettot.shape[0],"|", \
      EionettotOk.shape[0],"|", \
      EionettotError.shape[0],"|",)
# Out:
# | 20210612 | 3170 | 936 | 2234 |

# %%
end = datetime.now()
print("Ended: ", end) 
print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))
# Out:
# Ended:  2021-06-12 10:57:13.256192
# Time elapsed (hh:mm:ss.ms) 0:03:07.412235
